# %% [markdown]
# ### DRUG REPURPOSING ON CNS DRUGS

# %%
import numpy as np
import pandas as pd
import keras, os, pickle

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as MSE

from sklearn.model_selection import cross_validate, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from time import time

from keras.models import Sequential
from keras.layers import Dense
from keras import regularizers
from keras.wrappers.scikit_learn import KerasRegressor # this is for making a model like every other in scikit
import  matplotlib.pyplot as plt

np.random.seed(42)
from tensorflow.random import set_seed
set_seed(42)

# %%
Interactions_train = []    
with open("Interactions_Trainset.tab",'r') as f:
    for line in f:
        tokens = line.split()
        # 'Target-ID', 'Compound-ID', 'pIC50'  
        Interactions_train.append( [tokens[0], tokens[1], float(tokens[2]) ])

Anitiviral_train = []    
with open("drugs.tab",'r') as f:
    for line in f:
        tokens = line.split()
        #Compound-ID'
        Anitiviral_train.append( [tokens[0]])        
        
Interactions_valid = []        
with open("Interactions_Validset.tab",'r') as f:
    for line in f:
        tokens = line.split()
        # 'Target-ID', 'Compound-ID', 'pIC50'  
        Interactions_valid.append( [tokens[0], tokens[1], float(tokens[2]) ])

Interactions = [x for x in Interactions_train]
Interactions.extend(Interactions_valid)
# we use a dataframe to quickly sort targets wrt #compounds:
DF = pd.DataFrame( Interactions, columns =['Target-ID', 'Compound-ID','Std-value']) 
temp = DF.groupby(['Target-ID']).agg('count').sort_values(by='Compound-ID') # count the number of molecules
Targets = list(temp.index)
Compounds = np.unique(DF['Compound-ID'])
del temp, DF

nT=len(Targets); nC=len(Compounds)

print("There are {0} targets are present".format(nT))


# first we need to prepare each fp as a feature vector
Fingerprints={} # this contains one list per fingerprint - not efficient...
with open('drugs_Fingerprints.tab', 'r') as f:
    header = f.readline()
    for line in f:
        # each line is Comp-ID, SMILES, FP
        tokens = line.split()
        # we keep only those compounds which have FPs
        #print(tokens)
        fp = [int(c) for c in tokens[2] ]
        Fingerprints[ tokens[0] ] = fp
            
print("%d fingerprints were loaded!" % len(Fingerprints))
#print(Fingerprints["441300"])
# data standardisation - no need after using pIC50 !
values = [x[2] for x in Interactions]
#print("Stats for values : {0} | {1}".format(np.mean(values), np.std(values)))
#print("Antiviral Drugs", Fingerprints['2022'])
# Out:
# There are 110 targets are present
# 1690 fingerprints were loaded!

# %%
from scipy.stats import sem
from scipy.stats import t as tstat
def Imputer(model, NewID, Fingerprints, threshold=0.2):
    
    X_new = []
    #print("Compund ID's List", NewID)
    for cid in NewID:
        #print("For Compound Id : ", cid)
        x_test = np.array( Fingerprints[cid] ).reshape(1,-1)
        preds=[]
        for DTR in model.estimators_:
            #print("Pred-score from model", DTR.predict(x_test))
            preds.append(DTR.predict(x_test) )
        std_err = sem(preds)
        #print("stderr", std_err)
        h = std_err * tstat.ppf((1 + 0.95) / 2, len(preds) - 1)
        #print("Pred-score from model", h)
        if 2*h<=threshold:
            X_new.append( [ cid, np.mean(preds)] )
            print("Interaction found for Compound-id : ", cid)
            print("Prediction Score : ", np.mean(preds))
        #else:
            #print("No Interaction found!!")
    if len(X_new)>0:
        print("{0} new values were imputed!".format(len(X_new)))
    else:
        print("No confident values were found.")
    return X_new

# %%
Target_info = {} # this is a "global" variable
theta=0.2
count=0
def listToString(s):
    str1 = " "
    return (str1.join(s))
    
count = 1
for target in Targets:
    Target_info[target] = {}
    print("--------------------------------------------------------------------------------------------------------------------")
    print("Target {0} is: {1}".format(count, target))
    count = count + 1
    # define the train set
    X_train=[]; Y_train=[]
    Train_CIDs = []
    for point in Anitiviral_train:
        #fingerprint of pubchem compound id
        #print(point[0])
        if point[0] != 'Abacavir':
            X_train.append( Fingerprints[point[0]])
            Train_CIDs.append( point[0] )
        #print(Train_CIDs)
        #Y_train.append( float(point[2]) )


    #Target_info[target]['train_size']=len(Y_train) # add info

    with open( 'D:/Sem8_FYP/TrainedModals/RF_'+target+'_'+'pIC50new.sav', 'rb') as f:
            MODEL = pickle.load( f )

    #Target_info[target]['first_r2'] = MODEL.score( X_train,  Y_train) # add info
    #print("Evaluation without imputation = %.4f " % Target_info[target]["first_r2"] )    

    print("Imputing confident values...")
    X_new = [1] # just a trigger for the next loop
    while  (len(X_new)>0) :
        # we need to stop after we have no new predictions or we have enough (10K+)
        # update the train set
        NewIDs = [x for x in Train_CIDs] # terra incognito
        X_new = Imputer(MODEL, NewIDs, Fingerprints, threshold=theta)
        break
# Out:
# --------------------------------------------------------------------------------------------------------------------
# Target 1 is: CHEMBL5122
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 2 is: CHEMBL2095942
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 3 is: CHEMBL3116
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 4 is: CHEMBL3430907
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 5 is: CHEMBL4203
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 6 is: CHEMBL3797
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 7 is: CHEMBL2208
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 8 is: CHEMBL2111414
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 9 is: CHEMBL1906
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 10 is: CHEMBL3961
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 11 is: CHEMBL4070
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 12 is: CHEMBL4036
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 13 is: CHEMBL3983
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 14 is: CHEMBL4040
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 15 is: CHEMBL4898
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 16 is: CHEMBL3024
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 17 is: CHEMBL2095227
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 18 is: CHEMBL4376
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 19 is: CHEMBL2094115
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 20 is: CHEMBL3231
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 21 is: CHEMBL2094138
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 22 is: CHEMBL3009
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 23 is: CHEMBL2095217
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 24 is: CHEMBL5570
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 25 is: CHEMBL5314
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 26 is: CHEMBL5491
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 27 is: CHEMBL3629
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 28 is: CHEMBL5331
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 29 is: CHEMBL2850
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 30 is: CHEMBL2095188
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 31 is: CHEMBL5508
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 32 is: CHEMBL4816
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 33 is: CHEMBL4895
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 34 is: CHEMBL4937
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 35 is: CHEMBL3616
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 36 is: CHEMBL3905
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 37 is: CHEMBL2959
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 38 is: CHEMBL2599
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 39 is: CHEMBL2749
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 40 is: CHEMBL3476
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 41 is: CHEMBL2041
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 42 is: CHEMBL3582
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 43 is: CHEMBL3038469
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 44 is: CHEMBL2828
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 45 is: CHEMBL4224
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 46 is: CHEMBL1991
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 47 is: CHEMBL4439
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 48 is: CHEMBL3142
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 49 is: CHEMBL5543
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 50 is: CHEMBL2508
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 51 is: CHEMBL1955
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 52 is: CHEMBL4630
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 53 is: CHEMBL1907602
# Imputing confident values...
# Interaction found for Compound-id :  Aluminium
# Prediction Score :  -7.319209498689368
# Interaction found for Compound-id :  Iron
# Prediction Score :  -7.319209498689368
# Interaction found for Compound-id :  Lithium
# Prediction Score :  -7.319209498689368
# Interaction found for Compound-id :  Zinc
# Prediction Score :  -7.319209498689368
# 4 new values were imputed!
# --------------------------------------------------------------------------------------------------------------------
# Target 54 is: CHEMBL1907605
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 55 is: CHEMBL2842
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 56 is: CHEMBL2094127
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target 57 is: CHEMBL3234
# Imputing confident values...
# No confident values were found.
# --------------------------------------------------------------------------------------------------------------------
# Target
# Prediction Score :  -7.711576731538239
# Interaction found for Compound-id :  Methocarbamol
# Prediction Score :  -7.704496199987956
# Interaction found for Compound-id :  Metocurine
# Prediction Score :  -7.719113583760461
# Interaction found for Compound-id :  Miglitol
# Prediction Score :  -7.690932344871573
# Interaction found for Compound-id :  Mivacurium
# Prediction Score :  -7.708931883357028
# Interaction found for Compound-id :  Nitric_Oxide
# Prediction Score :  -7.711576731538239
# Interaction found for Compound-id :  Oxcarbazepine
# Prediction Score :  -7.7062882669243145
# Interaction found for Compound-id :  Pentamidine
# Prediction Score :  -7.7406290957129915
# Interaction found for Compound-id :  Pentolinium
# Prediction Score :  -7.686271041628329
# Interaction found for Compound-id :  Phenacemide
# Prediction Score :  -7.7062882669243145
# Interaction found for Compound-id :  Phenindione
# Prediction Score :  -7.7062882669243145
# Interaction found for Compound-id :  Podofilox
# Prediction Score :  -7.732503905803081
# Interaction found for Compound-id :  Pralidoxime
# Prediction Score :  -7.692629214089066
# Interaction found for Compound-id :  Selenium_Sulfide
# Prediction Score :  -7.711576731538239
# Interaction found for Compound-id :  Succinylcholine
# Prediction Score :  -7.721984504755727
# Interaction found for Compound-id :  Tolazamide
# Prediction Score :  -7.696515706028774
# Interaction found for Compound-id :  Venlafaxine
# Prediction Score :  -7.719893368225976
# Interaction found for Compound-id :  Vitamin_C
# Prediction Score :  -7.702315349119939
# Interaction found for Compound-id :  Zinc
# Prediction Score :  -7.711576731538239
# 45 new values were imputed!
# --------------------------------------------------------------------------------------------------------------------
# Target 110 is: CHEMBL279
# Imputing confident values...
# Interaction found for Compound-id :  Alendronate
# Prediction Score :  -5.895117975610247
# Interaction found for Compound-id :  Aluminium
# Prediction Score :  -5.904710040068326
# Interaction found for Compound-id :  Amantadine
# Prediction Score :  -5.904710040068326
# Interaction found for Compound-id :  Benzyl_alcohol
# Prediction Score :  -5.866768731091051
# Interaction found for Compound-id :  Choline
# Prediction Score :  -5.919553921084232
# Interaction found for Compound-id :  Cysteamine
# Prediction Score :  -5.897677243546588
# Interaction found for Compound-id :  Dalfampridine
# Prediction Score :  -5.884508554540665
# Interaction found for Compound-id :  Decamethonium
# Prediction Score :  -5.913915834165284
# Interaction found for Compound-id :  Dimercaprol
# Prediction Score :  -5.897677243546588
# Interaction found for Compound-id :  Dopamine
# Prediction Score :  -5.871409868867663
# Interaction found for Compound-id :  Iron
# Prediction Score :  -5.904710040068326
# Interaction found for Compound-id :  Lithium
# Prediction Score :  -5.904710040068326
# Interaction found for Compound-id :  Pentamidine
# Prediction Score :  -5.9010278872419315
# Interaction found for Compound-id :  Pentolinium
# Prediction Score :  -5.905126651883318
# Interaction found for Compound-id :  Phenelzine
# Prediction Score :  -5.890132696051917
# Interaction found for Compound-id :  Phenol
# Prediction Score :  -5.890132696051917
# Interaction found for Compound-id :  Piperazine
# Prediction Score :  -5.917037208679438
# Interaction found for Compound-id :  Protriptyline
# Prediction Score :  -5.911569442466539
# Interaction found for Compound-id :  Pyridoxine
# Prediction Score :  -5.879654028445163
# Interaction found for Compound-id :  Rasagiline
# Prediction Score :  -5.900738200574898
# Interaction found for Compound-id :  Spermine
# Prediction Score :  -5.917037208679438
# Interaction found for Compound-id :  Tranylcypromine
# Prediction Score :  -5.890132696051917
# Interaction found for Compound-id :  Zinc
# Prediction Score :  -5.904710040068326
# 23 new values were imputed!
